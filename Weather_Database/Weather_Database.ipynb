# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
# Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mushie
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | warwick
# Processing Record 5 of Set 1 | nioro
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | pak thong chai
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | ahipara
# Processing Record 13 of Set 1 | taoudenni
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 1 | karasjok
# Processing Record 17 of Set 1 | dhidhdhoo
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | stroud
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | high level
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | ayr
# Processing Record 25 of Set 1 | tongren
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | puerto escondido
# Processing Record 28 of Set 1 | lewiston
# Processing Record 29 of Set 1 | victoria
# Processing Record 30 of Set 1 | porto de moz
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | vardo
# Processing Record 33 of Set 1 | maunabo
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | flinders
# Processing Record 36 of Set 1 | norman wells
# Processing Record 37 of Set 1 | nyurba
# Processing Record 38 of Set 1 | granville
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | marshall
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | newtownards
# Processing Record 45 of Set 1 | kurush
# Processing Record 46 of Set 1 | lompoc
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 1 | sao jose da coroa grande
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | kallaste
# Processing Record 2 of Set 2 | mayumba
# Processing Record 3 of Set 2 | kjopsvik
# Processing Record 4 of Set 2 | cayenne
# Processing Record 5 of Set 2 | okmulgee
# Processing Record 6 of Set 2 | nantucket
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | abu samrah
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | teguise
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | najran
# Processing Record 17 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 18 of Set 2 | sladkovo
# Processing Record 19 of Set 2 | rio gallegos
# Processing Record 20 of Set 2 | sur
# Processing Record 21 of Set 2 | goalpara
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | egvekinot
# Processing Record 24 of Set 2 | lata
# Processing Record 25 of Set 2 | cabo san lucas
# Processing Record 26 of Set 2 | fare
# Processing Record 27 of Set 2 | severo-kurilsk
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | muros
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | husavik
# Processing Record 33 of Set 2 | rawson
# Processing Record 34 of Set 2 | maua
# Processing Record 35 of Set 2 | vila franca do campo
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | atar
# Processing Record 40 of Set 2 | khatanga
# Processing Record 41 of Set 2 | niono
# Processing Record 42 of Set 2 | bonfim
# Processing Record 43 of Set 2 | san juan
# Processing Record 44 of Set 2 | sao joao da barra
# Processing Record 45 of Set 2 | ekibastuz
# Processing Record 46 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | loei
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | ponta delgada
# Processing Record 1 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 2 of Set 3 | taltal
# Processing Record 3 of Set 3 | nalut
# Processing Record 4 of Set 3 | jalu
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | cortez
# Processing Record 9 of Set 3 | plouzane
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | burnie
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | hermanus
# Processing Record 14 of Set 3 | amarillo
# Processing Record 15 of Set 3 | agirish
# Processing Record 16 of Set 3 | srivardhan
# Processing Record 17 of Set 3 | burica
# City not found. Skipping...
# Processing Record 18 of Set 3 | westport
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | samarai
# Processing Record 21 of Set 3 | azare
# Processing Record 22 of Set 3 | santarem
# Processing Record 23 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 3 | asau
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 3 | hofn
# Processing Record 28 of Set 3 | palmer
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | qaqortoq
# Processing Record 31 of Set 3 | gladstone
# Processing Record 32 of Set 3 | mecca
# Processing Record 33 of Set 3 | mahebourg
# Processing Record 34 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 3 | waynesboro
# Processing Record 36 of Set 3 | waingapu
# Processing Record 37 of Set 3 | tuktoyaktuk
# Processing Record 38 of Set 3 | muzhi
# Processing Record 39 of Set 3 | primo tapia
# Processing Record 40 of Set 3 | camacha
# Processing Record 41 of Set 3 | umm kaddadah
# Processing Record 42 of Set 3 | erie
# Processing Record 43 of Set 3 | haines junction
# Processing Record 44 of Set 3 | issia
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 3 | touros
# Processing Record 48 of Set 3 | xinzhou
# Processing Record 49 of Set 3 | indian head
# Processing Record 50 of Set 3 | northam
# Processing Record 1 of Set 4 | geraldton
# Processing Record 2 of Set 4 | port hedland
# Processing Record 3 of Set 4 | sao felix do xingu
# Processing Record 4 of Set 4 | cidreira
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | san cristobal
# Processing Record 7 of Set 4 | selenduma
# Processing Record 8 of Set 4 | avarua
# Processing Record 9 of Set 4 | timmins
# Processing Record 10 of Set 4 | rexburg
# Processing Record 11 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 12 of Set 4 | san ramon
# Processing Record 13 of Set 4 | te anau
# Processing Record 14 of Set 4 | hvammstangi
# City not found. Skipping...
# Processing Record 15 of Set 4 | auki
# Processing Record 16 of Set 4 | manzil salim
# Processing Record 17 of Set 4 | vanimo
# Processing Record 18 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 4 | baikunthpur
# Processing Record 20 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 21 of Set 4 | dauphin
# Processing Record 22 of Set 4 | alofi
# Processing Record 23 of Set 4 | comodoro rivadavia
# Processing Record 24 of Set 4 | mount gambier
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | abapo
# Processing Record 27 of Set 4 | syasstroy
# Processing Record 28 of Set 4 | havoysund
# Processing Record 29 of Set 4 | new norfolk
# Processing Record 30 of Set 4 | mount isa
# Processing Record 31 of Set 4 | namibe
# Processing Record 32 of Set 4 | lincoln
# Processing Record 33 of Set 4 | manokwari
# Processing Record 34 of Set 4 | great falls
# Processing Record 35 of Set 4 | san andres
# Processing Record 36 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 4 | ocampo
# Processing Record 38 of Set 4 | alyangula
# Processing Record 39 of Set 4 | patacamaya
# Processing Record 40 of Set 4 | bonavista
# Processing Record 41 of Set 4 | tsabong
# Processing Record 42 of Set 4 | klamath falls
# Processing Record 43 of Set 4 | shache
# Processing Record 44 of Set 4 | butaritari
# Processing Record 45 of Set 4 | kabanjahe
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | liaocheng
# Processing Record 48 of Set 4 | coihaique
# Processing Record 49 of Set 4 | puerto madryn
# Processing Record 50 of Set 4 | nhulunbuy
# Processing Record 1 of Set 5 | rawah
# Processing Record 2 of Set 5 | kaitangata
# Processing Record 3 of Set 5 | labrea
# Processing Record 4 of Set 5 | srednekolymsk
# Processing Record 5 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 5 | lorengau
# Processing Record 7 of Set 5 | hithadhoo
# Processing Record 8 of Set 5 | corinto
# Processing Record 9 of Set 5 | tual
# Processing Record 10 of Set 5 | yarovoye
# Processing Record 11 of Set 5 | denizli
# Processing Record 12 of Set 5 | dalhousie
# Processing Record 13 of Set 5 | darnah
# Processing Record 14 of Set 5 | madimba
# Processing Record 15 of Set 5 | fortuna
# Processing Record 16 of Set 5 | gzhatsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | east london
# Processing Record 18 of Set 5 | bengkulu
# Processing Record 19 of Set 5 | kahului
# Processing Record 20 of Set 5 | sarai sidhu
# Processing Record 21 of Set 5 | mercedes
# Processing Record 22 of Set 5 | yulara
# Processing Record 23 of Set 5 | ibra
# Processing Record 24 of Set 5 | leningradskiy
# Processing Record 25 of Set 5 | talcahuano
# Processing Record 26 of Set 5 | pevek
# Processing Record 27 of Set 5 | vostok
# Processing Record 28 of Set 5 | sinnamary
# Processing Record 29 of Set 5 | baykit
# Processing Record 30 of Set 5 | ilulissat
# Processing Record 31 of Set 5 | vao
# Processing Record 32 of Set 5 | jertih
# Processing Record 33 of Set 5 | dingle
# Processing Record 34 of Set 5 | pak phanang
# Processing Record 35 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 5 | piryion
# City not found. Skipping...
# Processing Record 37 of Set 5 | necochea
# Processing Record 38 of Set 5 | bogorodskoye
# Processing Record 39 of Set 5 | tianpeng
# Processing Record 40 of Set 5 | leh
# Processing Record 41 of Set 5 | mitsamiouli
# Processing Record 42 of Set 5 | saint-philippe
# Processing Record 43 of Set 5 | jacareacanga
# Processing Record 44 of Set 5 | komsomolskiy
# Processing Record 45 of Set 5 | tangshan
# Processing Record 46 of Set 5 | onda
# Processing Record 47 of Set 5 | meulaboh
# Processing Record 48 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 50 of Set 5 | villachuato
# Processing Record 1 of Set 6 | panalingaan
# Processing Record 2 of Set 6 | aklavik
# Processing Record 3 of Set 6 | caravelas
# Processing Record 4 of Set 6 | torbay
# Processing Record 5 of Set 6 | dunedin
# Processing Record 6 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 7 of Set 6 | roald
# Processing Record 8 of Set 6 | bambous virieux
# Processing Record 9 of Set 6 | tete
# Processing Record 10 of Set 6 | ust-tsilma
# Processing Record 11 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 6 | reconquista
# Processing Record 13 of Set 6 | thinadhoo
# Processing Record 14 of Set 6 | paytug
# City not found. Skipping...
# Processing Record 15 of Set 6 | hamilton
# Processing Record 16 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 6 | pincher creek
# Processing Record 18 of Set 6 | bethel
# Processing Record 19 of Set 6 | hambantota
# Processing Record 20 of Set 6 | angoche
# Processing Record 21 of Set 6 | rosario
# Processing Record 22 of Set 6 | ayagoz
# Processing Record 23 of Set 6 | nago
# Processing Record 24 of Set 6 | tabou
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | olinda
# Processing Record 27 of Set 6 | vernon
# Processing Record 28 of Set 6 | huron
# Processing Record 29 of Set 6 | sobolevo
# Processing Record 30 of Set 6 | general pico
# Processing Record 31 of Set 6 | mehamn
# Processing Record 32 of Set 6 | kearney
# Processing Record 33 of Set 6 | akyab
# Processing Record 34 of Set 6 | puerto ayacucho
# Processing Record 35 of Set 6 | matagami
# Processing Record 36 of Set 6 | clyde river
# Processing Record 37 of Set 6 | nola
# Processing Record 38 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 39 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 40 of Set 6 | pacific grove
# Processing Record 41 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 42 of Set 6 | pierre
# Processing Record 43 of Set 6 | emba
# Processing Record 44 of Set 6 | pedernales
# Processing Record 45 of Set 6 | aykhal
# Processing Record 46 of Set 6 | rosarito
# Processing Record 47 of Set 6 | maniitsoq
# Processing Record 48 of Set 6 | puri
# Processing Record 49 of Set 6 | talnakh
# Processing Record 50 of Set 6 | elizabeth city
# Processing Record 1 of Set 7 | majene
# Processing Record 2 of Set 7 | chokurdakh
# Processing Record 3 of Set 7 | trogir
# Processing Record 4 of Set 7 | takhli
# Processing Record 5 of Set 7 | hasaki
# Processing Record 6 of Set 7 | manamadurai
# Processing Record 7 of Set 7 | machali
# Processing Record 8 of Set 7 | dedougou
# Processing Record 9 of Set 7 | hualmay
# Processing Record 10 of Set 7 | saint anthony
# Processing Record 11 of Set 7 | carbondale
# Processing Record 12 of Set 7 | sibu
# Processing Record 13 of Set 7 | langham
# Processing Record 14 of Set 7 | tshikapa
# Processing Record 15 of Set 7 | palafrugell
# Processing Record 16 of Set 7 | xuchang
# Processing Record 17 of Set 7 | pervomayskiy
# Processing Record 18 of Set 7 | ancud
# Processing Record 19 of Set 7 | anshun
# Processing Record 20 of Set 7 | visby
# Processing Record 21 of Set 7 | belaya gora
# Processing Record 22 of Set 7 | berlevag
# Processing Record 23 of Set 7 | cutervo
# Processing Record 24 of Set 7 | olafsvik
# Processing Record 25 of Set 7 | narsaq
# Processing Record 26 of Set 7 | cherskiy
# Processing Record 27 of Set 7 | luis correia
# Processing Record 28 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 7 | mao
# Processing Record 30 of Set 7 | mattru
# Processing Record 31 of Set 7 | emerald
# Processing Record 32 of Set 7 | sao filipe
# Processing Record 33 of Set 7 | farmington
# Processing Record 34 of Set 7 | bara
# Processing Record 35 of Set 7 | fairbanks
# Processing Record 36 of Set 7 | teul
# City not found. Skipping...
# Processing Record 37 of Set 7 | weinsberg
# Processing Record 38 of Set 7 | garden city
# Processing Record 39 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 7 | bloemfontein
# Processing Record 41 of Set 7 | la rioja
# Processing Record 42 of Set 7 | pavia
# Processing Record 43 of Set 7 | doctor juan leon mallorquin
# Processing Record 44 of Set 7 | krasnoslobodsk
# Processing Record 45 of Set 7 | charters towers
# Processing Record 46 of Set 7 | khani
# Processing Record 47 of Set 7 | ewa beach
# Processing Record 48 of Set 7 | henderson
# Processing Record 49 of Set 7 | coos bay
# Processing Record 50 of Set 7 | keetmanshoop
# Processing Record 1 of Set 8 | kruisfontein
# Processing Record 2 of Set 8 | sabang
# Processing Record 3 of Set 8 | mariental
# Processing Record 4 of Set 8 | yar-sale
# Processing Record 5 of Set 8 | ryotsu
# Processing Record 6 of Set 8 | progreso
# Processing Record 7 of Set 8 | vestmannaeyjar
# Processing Record 8 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 8 | gillette
# Processing Record 10 of Set 8 | vallenar
# Processing Record 11 of Set 8 | povenets
# Processing Record 12 of Set 8 | awjilah
# Processing Record 13 of Set 8 | biltine
# Processing Record 14 of Set 8 | laguna
# Processing Record 15 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 8 | gigmoto
# Processing Record 17 of Set 8 | el cope
# Processing Record 18 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 8 | qasigiannguit
# Processing Record 20 of Set 8 | nouadhibou
# Processing Record 21 of Set 8 | jatai
# Processing Record 22 of Set 8 | ternate
# Processing Record 23 of Set 8 | port lincoln
# Processing Record 24 of Set 8 | brae
# Processing Record 25 of Set 8 | baijiantan
# Processing Record 26 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 8 | palu
# Processing Record 28 of Set 8 | wenchi
# Processing Record 29 of Set 8 | placido de castro
# Processing Record 30 of Set 8 | chapada dos guimaraes
# Processing Record 31 of Set 8 | ostrovnoy
# Processing Record 32 of Set 8 | nanortalik
# Processing Record 33 of Set 8 | constitucion
# Processing Record 34 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 8 | bambanglipuro
# Processing Record 36 of Set 8 | tabuk
# Processing Record 37 of Set 8 | vila velha
# Processing Record 38 of Set 8 | matara
# Processing Record 39 of Set 8 | kattivakkam
# Processing Record 40 of Set 8 | beloha
# Processing Record 41 of Set 8 | pauini
# Processing Record 42 of Set 8 | san juan evangelista
# Processing Record 43 of Set 8 | guelengdeng
# City not found. Skipping...
# Processing Record 44 of Set 8 | krasnoarmeyskoye
# Processing Record 45 of Set 8 | barra
# Processing Record 46 of Set 8 | beringovskiy
# Processing Record 47 of Set 8 | esperance
# Processing Record 48 of Set 8 | isangel
# Processing Record 49 of Set 8 | riyadh
# Processing Record 50 of Set 8 | markivka
# Processing Record 1 of Set 9 | vilyuysk
# Processing Record 2 of Set 9 | cradock
# Processing Record 3 of Set 9 | eyl
# Processing Record 4 of Set 9 | surt
# Processing Record 5 of Set 9 | raudeberg
# Processing Record 6 of Set 9 | lagoa
# Processing Record 7 of Set 9 | poum
# Processing Record 8 of Set 9 | gravdal
# Processing Record 9 of Set 9 | tezu
# Processing Record 10 of Set 9 | korla
# Processing Record 11 of Set 9 | batemans bay
# Processing Record 12 of Set 9 | arman
# Processing Record 13 of Set 9 | mitchelstown
# Processing Record 14 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 15 of Set 9 | shellbrook
# Processing Record 16 of Set 9 | yumen
# Processing Record 17 of Set 9 | maragogi
# Processing Record 18 of Set 9 | galle
# Processing Record 19 of Set 9 | asasa
# Processing Record 20 of Set 9 | sioux lookout
# Processing Record 21 of Set 9 | kalmunai
# Processing Record 22 of Set 9 | tautira
# Processing Record 23 of Set 9 | mehriz
# Processing Record 24 of Set 9 | nanakuli
# Processing Record 25 of Set 9 | turukhansk
# Processing Record 26 of Set 9 | bundaberg
# Processing Record 27 of Set 9 | saint-francois
# Processing Record 28 of Set 9 | truro
# Processing Record 29 of Set 9 | maceio
# Processing Record 30 of Set 9 | mayo
# Processing Record 31 of Set 9 | turan
# Processing Record 32 of Set 9 | lipari
# Processing Record 33 of Set 9 | hokitika
# Processing Record 34 of Set 9 | brzeg dolny
# Processing Record 35 of Set 9 | puerto carreno
# Processing Record 36 of Set 9 | nakasongola
# Processing Record 37 of Set 9 | jimma
# Processing Record 38 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 9 | zhanaozen
# Processing Record 40 of Set 9 | ipixuna
# Processing Record 41 of Set 9 | port hardy
# Processing Record 42 of Set 9 | nelson bay
# Processing Record 43 of Set 9 | ucluelet
# Processing Record 44 of Set 9 | tilichiki
# Processing Record 45 of Set 9 | kununurra
# Processing Record 46 of Set 9 | kavieng
# Processing Record 47 of Set 9 | storozhevaya
# Processing Record 48 of Set 9 | tura
# Processing Record 49 of Set 9 | coquimbo
# Processing Record 50 of Set 9 | mogwase
# Processing Record 1 of Set 10 | san fernando
# Processing Record 2 of Set 10 | salzgitter
# Processing Record 3 of Set 10 | azuaga
# Processing Record 4 of Set 10 | brownsburg
# Processing Record 5 of Set 10 | moindou
# Processing Record 6 of Set 10 | chachapoyas
# Processing Record 7 of Set 10 | akureyri
# Processing Record 8 of Set 10 | roma
# Processing Record 9 of Set 10 | mormugao
# Processing Record 10 of Set 10 | kapuskasing
# Processing Record 11 of Set 10 | los llanos de aridane
# Processing Record 12 of Set 10 | xining
# Processing Record 13 of Set 10 | kpandu
# Processing Record 14 of Set 10 | mogadishu
# Processing Record 15 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 16 of Set 10 | boende
# Processing Record 17 of Set 10 | chadan
# Processing Record 18 of Set 10 | tacoronte
# Processing Record 19 of Set 10 | avera
# Processing Record 20 of Set 10 | scarborough
# Processing Record 21 of Set 10 | yining
# Processing Record 22 of Set 10 | kungurtug
# Processing Record 23 of Set 10 | natalinsk
# Processing Record 24 of Set 10 | alihe
# Processing Record 25 of Set 10 | itarema
# Processing Record 26 of Set 10 | stolin
# Processing Record 27 of Set 10 | la pila
# Processing Record 28 of Set 10 | sines
# Processing Record 29 of Set 10 | kirensk
# Processing Record 30 of Set 10 | baboua
# City not found. Skipping...
# Processing Record 31 of Set 10 | royan
# Processing Record 32 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 33 of Set 10 | teya
# Processing Record 34 of Set 10 | innisfail
# Processing Record 35 of Set 10 | esmeraldas
# Processing Record 36 of Set 10 | bayir
# Processing Record 37 of Set 10 | sola
# Processing Record 38 of Set 10 | juneau
# Processing Record 39 of Set 10 | inuvik
# Processing Record 40 of Set 10 | negombo
# Processing Record 41 of Set 10 | luganville
# Processing Record 42 of Set 10 | san giuseppe jato
# Processing Record 43 of Set 10 | faanui
# Processing Record 44 of Set 10 | saint-joseph
# Processing Record 45 of Set 10 | kohat
# Processing Record 46 of Set 10 | chimoio
# Processing Record 47 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 10 | kavaratti
# Processing Record 49 of Set 10 | singaparna
# Processing Record 50 of Set 10 | san patricio
# Processing Record 1 of Set 11 | tall kayf
# Processing Record 2 of Set 11 | sorland
# Processing Record 3 of Set 11 | verkhnevilyuysk
# Processing Record 4 of Set 11 | abu dhabi
# Processing Record 5 of Set 11 | yeehaw junction
# City not found. Skipping...
# Processing Record 6 of Set 11 | amol
# Processing Record 7 of Set 11 | fairview
# Processing Record 8 of Set 11 | sorgun
# Processing Record 9 of Set 11 | kenitra
# Processing Record 10 of Set 11 | werda
# Processing Record 11 of Set 11 | wajima
# Processing Record 12 of Set 11 | iringa
# Processing Record 13 of Set 11 | kargasok
# Processing Record 14 of Set 11 | alta floresta
# Processing Record 15 of Set 11 | sitka
# Processing Record 16 of Set 11 | bud
# Processing Record 17 of Set 11 | araouane
# Processing Record 18 of Set 11 | bathsheba
# Processing Record 19 of Set 11 | manhattan
# Processing Record 20 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 11 | port hawkesbury
# Processing Record 22 of Set 11 | iqaluit
# Processing Record 23 of Set 11 | kruszwica
# Processing Record 24 of Set 11 | cockburn town
# Processing Record 25 of Set 11 | angangxi
# City not found. Skipping...
# Processing Record 26 of Set 11 | katangli
# Processing Record 27 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 11 | kokologo
# Processing Record 29 of Set 11 | helong
# Processing Record 30 of Set 11 | elk city
# Processing Record 31 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 32 of Set 11 | opuwo
# Processing Record 33 of Set 11 | kaeo
# Processing Record 34 of Set 11 | makat
# Processing Record 35 of Set 11 | balkanabat
# Processing Record 36 of Set 11 | bodden town
# Processing Record 37 of Set 11 | mbini
# Processing Record 38 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 11 | codrington
# Processing Record 40 of Set 11 | bongandanga
# Processing Record 41 of Set 11 | port blair
# Processing Record 42 of Set 11 | omboue
# Processing Record 43 of Set 11 | le moule
# Processing Record 44 of Set 11 | karratha
# Processing Record 45 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 11 | plastun
# Processing Record 47 of Set 11 | ust-ilimsk
# Processing Record 48 of Set 11 | greeneville
# Processing Record 49 of Set 11 | port keats
# Processing Record 50 of Set 11 | huarmey
# Processing Record 1 of Set 12 | honiara
# Processing Record 2 of Set 12 | ribeira brava
# Processing Record 3 of Set 12 | tecoanapa
# Processing Record 4 of Set 12 | harper
# Processing Record 5 of Set 12 | pangkalanbuun
# Processing Record 6 of Set 12 | salalah
# Processing Record 7 of Set 12 | zima
# Processing Record 8 of Set 12 | barra do garcas
# Processing Record 9 of Set 12 | balod
# Processing Record 10 of Set 12 | collie
# Processing Record 11 of Set 12 | laje
# Processing Record 12 of Set 12 | olden
# Processing Record 13 of Set 12 | iberia
# Processing Record 14 of Set 12 | tuatapere
# Processing Record 15 of Set 12 | shelburne
# Processing Record 16 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 12 | tateyama
# Processing Record 18 of Set 12 | goderich
# Processing Record 19 of Set 12 | legionowo
# Processing Record 20 of Set 12 | morant bay
# Processing Record 21 of Set 12 | bethanien
# Processing Record 22 of Set 12 | coahuayana
# Processing Record 23 of Set 12 | daru
# Processing Record 24 of Set 12 | faya
# Processing Record 25 of Set 12 | guerrero negro
# Processing Record 26 of Set 12 | perth
# Processing Record 27 of Set 12 | kloulklubed
# Processing Record 28 of Set 12 | copiapo
# Processing Record 29 of Set 12 | kendari
# Processing Record 30 of Set 12 | broken hill
# Processing Record 31 of Set 12 | berdyuzhye
# City not found. Skipping...
# Processing Record 32 of Set 12 | gobabis
# Processing Record 33 of Set 12 | hay river
# Processing Record 34 of Set 12 | solnechnyy
# Processing Record 35 of Set 12 | edd
# Processing Record 36 of Set 12 | marzuq
# Processing Record 37 of Set 12 | murgab
# Processing Record 38 of Set 12 | tiksi
# Processing Record 39 of Set 12 | quincy
# Processing Record 40 of Set 12 | shetpe
# Processing Record 41 of Set 12 | tromso
# Processing Record 42 of Set 12 | neiafu
# Processing Record 43 of Set 12 | listvyanskiy
# Processing Record 44 of Set 12 | dumas
# Processing Record 45 of Set 12 | cochabamba
# Processing Record 46 of Set 12 | broome
# Processing Record 47 of Set 12 | belmonte
# Processing Record 48 of Set 12 | yafran
# Processing Record 49 of Set 12 | sal rei
# Processing Record 50 of Set 12 | carutapera
# Processing Record 1 of Set 13 | upington
# Processing Record 2 of Set 13 | churapcha
# Processing Record 3 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 13 | bereda
# Processing Record 5 of Set 13 | nouakchott
# Processing Record 6 of Set 13 | sisimiut
# Processing Record 7 of Set 13 | verkhoyansk
# Processing Record 8 of Set 13 | houma
# Processing Record 9 of Set 13 | pathein
# Processing Record 10 of Set 13 | lalmohan
# Processing Record 11 of Set 13 | energetik
# Processing Record 12 of Set 13 | luba
# Processing Record 13 of Set 13 | pisco
# Processing Record 14 of Set 13 | aksu
# Processing Record 15 of Set 13 | bayan
# Processing Record 16 of Set 13 | shieli
# Processing Record 17 of Set 13 | lianzhou
# Processing Record 18 of Set 13 | yagunovskiy
# Processing Record 19 of Set 13 | kudahuvadhoo
# Processing Record 20 of Set 13 | langsa
# Processing Record 21 of Set 13 | port-gentil
# Processing Record 22 of Set 13 | anadyr
# Processing Record 23 of Set 13 | klobuck
# Processing Record 24 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 13 | ukiah
# Processing Record 26 of Set 13 | paamiut
# Processing Record 27 of Set 13 | domoni
# Processing Record 28 of Set 13 | nisporeni
# Processing Record 29 of Set 13 | todos santos
# Processing Record 30 of Set 13 | piedras negras
# Processing Record 31 of Set 13 | clearlake
# Processing Record 32 of Set 13 | singaraja
# Processing Record 33 of Set 13 | semnan
# Processing Record 34 of Set 13 | sicamous
# Processing Record 35 of Set 13 | albemarle
# Processing Record 36 of Set 13 | north bend
# Processing Record 37 of Set 13 | bilibino
# Processing Record 38 of Set 13 | aswan
# Processing Record 39 of Set 13 | motygino
# Processing Record 40 of Set 13 | garissa
# Processing Record 41 of Set 13 | arua
# Processing Record 42 of Set 13 | lena
# Processing Record 43 of Set 13 | gubkinskiy
# Processing Record 44 of Set 13 | kisangani
# Processing Record 45 of Set 13 | gat
# Processing Record 46 of Set 13 | opobo
# City not found. Skipping...
# Processing Record 47 of Set 13 | labuhan
# Processing Record 48 of Set 13 | tres arroyos
# Processing Record 49 of Set 13 | valea mare
# Processing Record 50 of Set 13 | vanderhoof
# Processing Record 1 of Set 14 | at-bashi
# Processing Record 2 of Set 14 | taguatinga
# Processing Record 3 of Set 14 | bubaque
# Processing Record 4 of Set 14 | tommot
# Processing Record 5 of Set 14 | alekseyevsk
# Processing Record 6 of Set 14 | grand gaube
# Processing Record 7 of Set 14 | la ronge
# Processing Record 8 of Set 14 | huilong
# Processing Record 9 of Set 14 | pilas
# Processing Record 10 of Set 14 | longyearbyen
# Processing Record 11 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 14 | mezhdurechenskiy
# Processing Record 13 of Set 14 | luorong
# Processing Record 14 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 14 | chicama
# Processing Record 16 of Set 14 | pachora
# Processing Record 17 of Set 14 | pedasi
# Processing Record 18 of Set 14 | zyryanovskiy
# City not found. Skipping...
# Processing Record 19 of Set 14 | magadan
# Processing Record 20 of Set 14 | salinopolis
# Processing Record 21 of Set 14 | hirara
# Processing Record 22 of Set 14 | noshiro
# Processing Record 23 of Set 14 | ushtobe
# Processing Record 24 of Set 14 | henties bay
# Processing Record 25 of Set 14 | vilhena
# Processing Record 26 of Set 14 | great yarmouth
# Processing Record 27 of Set 14 | berea
# Processing Record 28 of Set 14 | pereyaslovskaya
# Processing Record 29 of Set 14 | proddatur
# Processing Record 30 of Set 14 | bandundu
# Processing Record 31 of Set 14 | rocha
# Processing Record 32 of Set 14 | sandwick
# Processing Record 33 of Set 14 | hobbs
# Processing Record 34 of Set 14 | canutama
# Processing Record 35 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 36 of Set 14 | alice springs
# Processing Record 37 of Set 14 | tambopata
# Processing Record 38 of Set 14 | whitianga
# Processing Record 39 of Set 14 | leshukonskoye
# Processing Record 40 of Set 14 | kabalo
# Processing Record 41 of Set 14 | trairi
# Processing Record 42 of Set 14 | kleck
# City not found. Skipping...
# Processing Record 43 of Set 14 | namatanai
# Processing Record 44 of Set 14 | ratnagiri
# Processing Record 45 of Set 14 | heswall
# Processing Record 46 of Set 14 | tiznit
# Processing Record 47 of Set 14 | alekseyevskaya
# Processing Record 48 of Set 14 | ulaangom
# Processing Record 49 of Set 14 | rassvet
# Processing Record 50 of Set 14 | yarmouth
# Processing Record 1 of Set 15 | nha trang
# Processing Record 2 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 3 of Set 15 | farafangana
# Processing Record 4 of Set 15 | zhigansk
# Processing Record 5 of Set 15 | tanete
# Processing Record 6 of Set 15 | talas
# Processing Record 7 of Set 15 | brigantine
# Processing Record 8 of Set 15 | parga
# Processing Record 9 of Set 15 | mataram
# Processing Record 10 of Set 15 | bozuyuk
# Processing Record 11 of Set 15 | ardakan
# Processing Record 12 of Set 15 | oistins
# Processing Record 13 of Set 15 | sentjur
# Processing Record 14 of Set 15 | muroto
# Processing Record 15 of Set 15 | quatre cocos
# Processing Record 16 of Set 15 | two hills
# Processing Record 17 of Set 15 | taywarah
# Processing Record 18 of Set 15 | nishihara
# Processing Record 19 of Set 15 | jishou
# Processing Record 20 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 21 of Set 15 | safranbolu
# Processing Record 22 of Set 15 | corowa
# Processing Record 23 of Set 15 | yeniseysk
# Processing Record 24 of Set 15 | meadow lake
# Processing Record 25 of Set 15 | bentiu
# Processing Record 26 of Set 15 | bitung
# Processing Record 27 of Set 15 | grindavik
# Processing Record 28 of Set 15 | portland
# Processing Record 29 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 15 | adrar
# Processing Record 31 of Set 15 | milazzo
# Processing Record 32 of Set 15 | manta
# Processing Record 33 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 15 | columbus
# Processing Record 35 of Set 15 | praia da vitoria
# Processing Record 36 of Set 15 | penzance
# Processing Record 37 of Set 15 | talavera de la reina
# Processing Record 38 of Set 15 | urosevac
# City not found. Skipping...
# Processing Record 39 of Set 15 | waipawa
# Processing Record 40 of Set 15 | beloretsk
# Processing Record 41 of Set 15 | luanda
# Processing Record 42 of Set 15 | kantang
# Processing Record 43 of Set 15 | ko samui
# Processing Record 44 of Set 15 | charyshskoye
# Processing Record 45 of Set 15 | deputatskiy
# Processing Record 46 of Set 15 | marrakesh
# Processing Record 47 of Set 15 | kazanskaya
# Processing Record 48 of Set 15 | duyun
# Processing Record 49 of Set 15 | hoa binh
# Processing Record 50 of Set 15 | kaduqli
# Processing Record 1 of Set 16 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 16 | katsuura
# Processing Record 3 of Set 16 | hirado
# Processing Record 4 of Set 16 | sao sebastiao
# Processing Record 5 of Set 16 | magaria
# Processing Record 6 of Set 16 | ornskoldsvik
# Processing Record 7 of Set 16 | bandipur
# Processing Record 8 of Set 16 | funtua
# Processing Record 9 of Set 16 | san quintin
# Processing Record 10 of Set 16 | kulhudhuffushi
# Processing Record 11 of Set 16 | pahrump
# Processing Record 12 of Set 16 | roebourne
# Processing Record 13 of Set 16 | gambela
# Processing Record 14 of Set 16 | wuchang
# Processing Record 15 of Set 16 | college
# Processing Record 16 of Set 16 | barra do bugres
# Processing Record 17 of Set 16 | benguela
# Processing Record 18 of Set 16 | liepaja
# Processing Record 19 of Set 16 | usinsk
# Processing Record 20 of Set 16 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 21 of Set 16 | kikwit
# Processing Record 22 of Set 16 | tabas
# Processing Record 23 of Set 16 | romanovka
# Processing Record 24 of Set 16 | mabaruma
# Processing Record 25 of Set 16 | ningbo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mushie      CD  -3.02   16.90     87.67        59          60
# 1     Yellowknife      CA  62.46 -114.35     19.40       100          90
# 2    Puerto Ayora      EC  -0.74  -90.35     73.00        68          99
# 3         Warwick      US  41.70  -71.42     69.01        63          20
# 4           Nioro      GM  13.35  -15.75    102.38        16           0
# 5          Atuona      PF  -9.80 -139.03     76.89        77           5
# 6    Punta Arenas      CL -53.15  -70.92     53.60        62          75
# 7  Pak Thong Chai      TH  14.72  102.03     75.99        99          19
# 8         Ushuaia      AR -54.80  -68.30     51.80        50          75
# 9       Jamestown      US  42.10  -79.24     51.80        66           1
#
#    Wind Speed Current Description
# 0        2.08       broken clouds
# 1        3.36     overcast clouds
# 2        8.01     overcast clouds
# 3        3.00          few clouds
# 4        9.60           clear sky
# 5       13.96           clear sky
# 6       19.46       broken clouds
# 7        7.16          few clouds
# 8       21.92       broken clouds
# 9        5.82           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
